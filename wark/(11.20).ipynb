# %% [markdown]
# <a href="https://colab.research.google.com/github/Keita062/Text_-Analysis_Charenge/blob/main/(11.20).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
from bs4 import BeautifulSoup

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
f = open("/content/演説全文.txt", "r")
content = f.read()
f.close()

# %%
# ファイルを読み込み
with open("/content/演説全文.txt", "r", encoding="utf-8") as f:
    lines = f.readlines()

# 改行や空白を取り除く
lines = [line.strip() for line in lines]

# DataFrameに変換
speach = pd.DataFrame(lines, columns=["speech_line"])

# 最初の5行を表示
speach.head()
# Out:
#                 speech_line
# 0                      演説全文
# 1                    一　はじめに
# 2
# 3  この度、第百二代内閣総理大臣に就任いたしました。
# 4            「すべての人に安心と安全を」

# %%
speach.shape
# Out:
# (120, 1)

# %%
print(speach.info())
print(speach.describe())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120 entries, 0 to 119
# Data columns (total 1 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   speech_line  120 non-null    object
# dtypes: object(1)
# memory usage: 1.1+ KB
# None
#        speech_line
# count          120
# unique          95
# top
# freq            25

# %%
import re
from collections import Counter

# %%
# テキストを1つの大きな文字列に結合
all_text = ' '.join(speach['speech_line'])

# 正規表現で単語に分割
words = re.findall(r'\w+', all_text)

# 単語ごとの出現回数を数える
word_count = Counter(words)

word_count
# Out:
# Counter({'演説全文': 1,
#          '一': 1,
#          'はじめに': 1,
#          'この度': 1,
#          '第百二代内閣総理大臣に就任いたしました': 1,
#          'すべての人に安心と安全を': 2,
#          '私は': 7,
#          '日本国内閣総理大臣として': 1,
#          '全身全霊を捧げ': 1,
#          '日本と日本の未来を守り抜いてまいります': 1,
#          'この決意を申し上げるに当たり': 1,
#          'まずは': 2,
#          '政治資金問題などをめぐり': 1,
#          '国民の政治不信を招いた事態について': 1,
#          '深い反省とともに触れねばなりません': 1,
#          '政治資金問題に際し': 1,
#          '岸田総理は': 1,
#          '自由民主党内の派閥解消や政治資金規正法改正などに取り組まれた後に': 1,
#          '所属議員が起こした事態について': 1,
#          '組織の長として責任を取るために退任されました': 1,
#          'これらは': 1,
#          '全て': 1,
#          '政治改革を前に進めるとの思いを持って決断されたものでした': 1,
#          'また': 5,
#          '岸田内閣の三年間は': 1,
#          '経済': 2,
#          'エネルギー政策': 1,
#          'こども政策': 1,
#          '安全保障政策': 1,
#          'そして外交政策など': 1,
#          '幅広い分野において': 1,
#          '具体的な成果が形になった三年でありました': 1,
#          '岸田総理の御尽力に': 1,
#          '心より敬意を表します': 1,
#          'その思いや実績を基に': 1,
# ...

# %%
# 出現回数でソート（降順）
sorted_word_count = word_count.most_common()

sorted_word_count
# Out:
# [('私は', 7),
#  ('また', 5),
#  ('そして', 4),
#  ('そのために', 4),
#  ('若者', 4),
#  ('防災', 3),
#  ('女性', 3),
#  ('すべての人に安心と安全を', 2),
#  ('まずは', 2),
#  ('経済', 2),
#  ('ルールを守る', 2),
#  ('日本を守る', 2),
#  ('国民を守る', 2),
#  ('地方を守る', 2),
#  ('女性の機会を守る', 2),
#  ('日本の未来を創り', 2),
#  ('外交', 2),
#  ('その際', 2),
#  ('これは', 2),
#  ('です', 2),
#  ('賃上げと投資が牽引する成長型経済', 2),
#  ('このため', 2),
#  ('満足度', 2),
#  ('減災', 2),
#  ('投資大国', 2),
#  ('しかし', 2),
#  ('演説全文', 1),
#  ('一', 1),
#  ('はじめに', 1),
#  ('この度', 1),
#  ('第百二代内閣総理大臣に就任いたしました', 1),
#  ('日本国内閣総理大臣として', 1),
#  ('全身全霊を捧げ', 1),
#  ('日本と日本の未来を守り抜いてまいります', 1),
#  ('この決意を申し上げるに当たり', 1),
#  ('政治資金問題などをめぐり', 1),
#  ('国民の政治不信を招いた事態について', 1),
#  ('深い反省とともに触れねばなりません', 1),
#  ('政治資金問題に際し', 1),
#  ('岸田総理は', 1),
#  ('自由民主党内の派閥解消や政治資金規正法改正などに取り組まれた後に', 1),
#  ('所属議員が起こした事態について', 1),
#  ('組織の長として責任を取るために退任されました', 1),
#  ('これらは', 1),
#  ('全て', 1),
#  ('政治改革を前に進めるとの思いを持って決断されたものでした', 1),
#  ('岸田内閣の三年間は', 1),
#  ('エネルギー政策', 1),
#  ('こども政策', 1),
#  ('安全保障政策', 1),
# ...
